# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
quran = pd.read_csv('ahkam_indexing/hisb_60_and_Al_fatihah_audio_with_transcript_and_MFCC_and_ahkam_indexing_v3.csv')

# %%
quran.columns
# Out:
# Index(['sura_no', 'sura_name_en', 'sura_name_ar', 'aya_no', 'aya_text',
#        'recitor_en', 'recitor_ar', 'recitor_reciting_aya_wav_path', 'mfcc',
#        'madd_6_Lazim', 'madd_246', 'madd_6', 'madd_2', 'Ikhfaa', 'Idgham',
#        'tafkhim', 'qalqala', 'imala'],
#       dtype='object')

# %%
quran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1192 entries, 0 to 1191
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   sura_no                        1192 non-null   float64
#  1   sura_name_en                   1192 non-null   object
#  2   sura_name_ar                   1192 non-null   object
#  3   aya_no                         1192 non-null   float64
#  4   aya_text                       1192 non-null   object
#  5   recitor_en                     1192 non-null   object
#  6   recitor_ar                     1192 non-null   object
#  7   recitor_reciting_aya_wav_path  1192 non-null   object
#  8   mfcc                           1192 non-null   object
#  9   madd_6_Lazim                   1192 non-null   object
#  10  madd_246                       1192 non-null   object
#  11  madd_6                         1192 non-null   object
# ...

# %%
missing_values = quran.isnull().sum()
missing_values
# Out:
# sura_no                          0
# sura_name_en                     0
# sura_name_ar                     0
# aya_no                           0
# aya_text                         0
# recitor_en                       0
# recitor_ar                       0
# recitor_reciting_aya_wav_path    0
# mfcc                             0
# madd_6_Lazim                     0
# madd_246                         0
# madd_6                           0
# madd_2                           0
# Ikhfaa                           0
# Idgham                           0
# tafkhim                          0
# qalqala                          0
# imala                            0
# dtype: int64

# %%
verse_distribution = quran.groupby(['recitor_en', 'sura_no']).size()
verse_distribution
# Out:
# recitor_en         sura_no
# Abdul Basit        1.0         7
#                    87.0       19
#                    88.0       26
#                    89.0       32
#                    90.0       20
#                               ..
# Yassin Al Jazaery  110.0       3
#                    111.0       5
#                    112.0       4
#                    113.0       5
#                    114.0       6
# Length: 116, dtype: int64

# %%
plt.figure(figsize=(3,5))
sns.set_style('darkgrid')
ax = sns.countplot(data=quran, y='recitor_en', palette='viridis')

for container in ax.containers:
    ax.bar_label(container, size=10, padding=2)

ax.set_title('Noumber of verses recited by each recitorer', fontweight='bold', fontsize=12)
ax.set_ylabel('Recitors', fontweight='bold')
ax.set_xlabel('Ayat', fontweight='bold')
ax.set_xticks([0, 50, 100, 150, 200, 250, 300])
        
plt.show()

# %%
quran = pd.read_csv('warsh_transcript/abdul_basit_recitor_reciting_with_transcript.csv')
Al_Fatihah = quran[quran['sura_no'] == 1]
quran = quran[(quran['sura_no'] >= 87) & (quran['sura_no'] <= 114)]
df = pd.concat([Al_Fatihah, quran])

# %%
plt.figure(figsize=(6,10))
sns.set_style('darkgrid')
ax = sns.countplot(data=df, y='sura_name_en', palette='husl')

for container in ax.containers:
    ax.bar_label(container, size=10, padding=2)

ax.set_title('Noumber of verses in each chapter', fontweight='bold', fontsize=12)
ax.set_ylabel('Chapters', fontweight='bold')
ax.set_xlabel('Verses', fontweight='bold')
ax.set_xticks([0, 5, 10, 15, 20, 25, 30, 35])
        
plt.show()
