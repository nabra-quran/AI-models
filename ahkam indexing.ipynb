# %%
import os
import pandas as pd

# %%
ahkam_indexing = pd.read_excel('ahkam_indexing/Ahkam in ayat hisb 60 + 001.xlsx')

# %%
repeated_df = pd.concat([ahkam_indexing]*3, ignore_index=True)
columns_to_keep = ["madd_6_Lazim", "madd_246", "madd_6", "madd_2",
                    "Ikhfaa", "Idgham", "tafkhim", "qalqala", "imala"]
new_df = repeated_df[columns_to_keep]

# %%
repeated_df
# Out:
#      surah  aya madd_6_Lazim    madd_246      madd_6      madd_2  \
# 0        1    1           []          []  [[36, 36]]  [[31, 31]]
# 1        1    2           []  [[24, 24]]          []  [[11, 11]]
# 2        1    3           []  [[21, 21]]          []          []
# 3        1    4           []  [[37, 37]]          []          []
# 4        1    5           []  [[36, 36]]          []  [[19, 19]]
# ..     ...  ...          ...         ...         ...         ...
# 889    114    2           []  [[14, 14]]          []          []
# 890    114    3           []  [[15, 15]]          []    [[4, 4]]
# 891    114    4           []  [[35, 35]]          []          []
# 892    114    5           []  [[38, 38]]          []          []
# 893    114    6           []  [[25, 25]]          []          []
#
#                    Ikhfaa              Idgham                         tafkhim  \
# 0                      []                  []                      [[18, 19]]
# ...

# %%
hisb60 = pd.read_csv('warsh_transcript/hisb_60_and_Al_fatihah_audio_with_transcript_and_MFCC.csv')

# %%
hisb60
# Out:
#      sura_no sura_name_en sura_name_ar  aya_no  \
# 0        1.0   Al-Fātiḥah   الفَاتِحة      1.0
# 1        1.0   Al-Fātiḥah   الفَاتِحة      2.0
# 2        1.0   Al-Fātiḥah   الفَاتِحة      3.0
# 3        1.0   Al-Fātiḥah   الفَاتِحة      4.0
# 4        1.0   Al-Fātiḥah   الفَاتِحة      5.0
# ..       ...          ...          ...     ...
# 889    114.0       An-Nās     النَّاس      2.0
# 890    114.0       An-Nās     النَّاس      3.0
# 891    114.0       An-Nās     النَّاس      4.0
# 892    114.0       An-Nās     النَّاس      5.0
# 893    114.0       An-Nās     النَّاس      6.0
#
#                                         aya_text        recitor_en  \
# 0      اِ۬لْحَمْدُ لِلهِ رَبِّ اِ۬لْعَٰلَمِينَ ١  Ibrahim_Aldosary
# 1                  اَ۬لرَّحْمَٰنِ اِ۬لرَّحِيمِ ٢  Ibrahim_Aldosary
# 2                    مَلِكِ يَوْمِ اِ۬لدِّينِۖ ٣  Ibrahim_Aldosary
# 3    إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُۖ ٤  Ibrahim_Aldosary
# ...

# %%
new_df
# Out:
#     madd_6_Lazim    madd_246      madd_6      madd_2                Ikhfaa  \
# 0             []          []  [[36, 36]]  [[31, 31]]                    []
# 1             []  [[24, 24]]          []  [[11, 11]]                    []
# 2             []  [[21, 21]]          []          []                    []
# 3             []  [[37, 37]]          []          []                    []
# 4             []  [[36, 36]]          []  [[19, 19]]                    []
# ..           ...         ...         ...         ...                   ...
# 889           []  [[14, 14]]          []          []            [[11, 13]]
# 890           []  [[15, 15]]          []    [[4, 4]]            [[12, 14]]
# 891           []  [[35, 35]]          []          []    [[2, 2], [32, 34]]
# 892           []  [[38, 38]]          []          []            [[35, 37]]
# 893           []  [[25, 25]]          []          []  [[12, 14], [22, 24]]
#
# ...

# %%
hisb_60_and_Al_fatihah_audio_with_transcript_and_MFCC_and_ahkam_indexing = pd.concat([hisb60, new_df], axis = 1)

# %%
hisb_60_and_Al_fatihah_audio_with_transcript_and_MFCC_and_ahkam_indexing
# Out:
#      sura_no sura_name_en sura_name_ar  aya_no  \
# 0        1.0   Al-Fātiḥah   الفَاتِحة      1.0
# 1        1.0   Al-Fātiḥah   الفَاتِحة      2.0
# 2        1.0   Al-Fātiḥah   الفَاتِحة      3.0
# 3        1.0   Al-Fātiḥah   الفَاتِحة      4.0
# 4        1.0   Al-Fātiḥah   الفَاتِحة      5.0
# ..       ...          ...          ...     ...
# 889    114.0       An-Nās     النَّاس      2.0
# 890    114.0       An-Nās     النَّاس      3.0
# 891    114.0       An-Nās     النَّاس      4.0
# 892    114.0       An-Nās     النَّاس      5.0
# 893    114.0       An-Nās     النَّاس      6.0
#
#                                         aya_text        recitor_en  \
# 0      اِ۬لْحَمْدُ لِلهِ رَبِّ اِ۬لْعَٰلَمِينَ ١  Ibrahim_Aldosary
# 1                  اَ۬لرَّحْمَٰنِ اِ۬لرَّحِيمِ ٢  Ibrahim_Aldosary
# 2                    مَلِكِ يَوْمِ اِ۬لدِّينِۖ ٣  Ibrahim_Aldosary
# 3    إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُۖ ٤  Ibrahim_Aldosary
# ...

# %%
hisb_60_and_Al_fatihah_audio_with_transcript_and_MFCC_and_ahkam_indexing.to_csv('ahkam_indexing/hisb_60_and_Al_fatihah_audio_with_transcript_and_MFCC_and_ahkam_indexing.csv', index = False)
